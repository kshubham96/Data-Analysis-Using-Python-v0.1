# %%
import pandas as pd
cmp = pd.read_excel('C:/Users/dell/Desktop/shubham_backup/Excel/CMP-Data-File.xlsx')

# %%
cmp.head()
# Out:
#      WEEK-OF               PROJECT-ID  DESIGN-ENGINEER        CURRENT-PACKAGE  \
# 0 2020-07-12          TL13804 Z519147  Marissa Metzger        4.1 -- FINAL OH
# 1 2020-07-12        TL13804 Z519147-F       Ryan Gokey       3.4 -- 90 FOUND.
# 2 2020-07-12    TL13810 Z97249 Z96761      Nico Pecori  5.1 -- CONST. SUPPORT
# 3 2020-07-12      TL612 TL604 Z279897     Shiva Kaitha    2.2 -- 60 OH DESIGN
# 4 2020-07-12  TL13834 Z224371 P193412  Marissa Metzger          1 -- FIELDING
#
#         PACKAGE-STATUS     PACKAGE- ROADBLOCK    BIC       NEXT-SUBMITTAL  \
# 0        4 -- Approved           No Roadblock    NaN        Not Scheduled
# 1  5 -- Hold/Cancelled           No Roadblock    NaN        Not Scheduled
# 2       3 -- Roadblock  Submitted / In-Review  SDG&E        Not Scheduled
# 3  5 -- Hold/Cancelled                  Other   BMcD        Not Scheduled
# 4     2 -- In Progress           No Roadblock   ASEC  2020-07-24 00:00:00
#
#                    NEXT-SUBMITTAL DETAIL  \
# ...

# %%
type(cmp)
# Out:
# pandas.core.frame.DataFrame

# %%
cmp = pd.read_excel('C:/Users/dell/Desktop/shubham_backup/Excel/CMP-Data-File.xlsx',nrows = 4)
cmp
# Out:
#      WEEK-OF             PROJECT-ID  DESIGN-ENGINEER        CURRENT-PACKAGE  \
# 0 2020-07-12        TL13804 Z519147  Marissa Metzger        4.1 -- FINAL OH
# 1 2020-07-12      TL13804 Z519147-F       Ryan Gokey       3.4 -- 90 FOUND.
# 2 2020-07-12  TL13810 Z97249 Z96761      Nico Pecori  5.1 -- CONST. SUPPORT
# 3 2020-07-12    TL612 TL604 Z279897     Shiva Kaitha    2.2 -- 60 OH DESIGN
#
#         PACKAGE-STATUS     PACKAGE- ROADBLOCK    BIC NEXT-SUBMITTAL  \
# 0        4 -- Approved           No Roadblock    NaN  Not Scheduled
# 1  5 -- Hold/Cancelled           No Roadblock    NaN  Not Scheduled
# 2       3 -- Roadblock  Submitted / In-Review  SDG&E  Not Scheduled
# 3  5 -- Hold/Cancelled                  Other   BMcD  Not Scheduled
#
#                    NEXT-SUBMITTAL DETAIL  \
# 0                                   None
# 1                                   None
# 2  Switch Bracket Design Review -- Stan.
# 3                                   None
#
# ...

# %%
import numpy as np
cmp = pd.read_excel('C:/Users/dell/Desktop/shubham_backup/Excel/CMP-Data-File.xlsx','CMP-D')
cmp.select_dtypes(include = [np.number]).dtypes
# Out:
# DIST DESIGNER     float64
# HR-TO-DATE        float64
# BILLED-TO-DATE    float64
# dtype: object

# %%
cmp.describe()
# Out:
#        DIST DESIGNER  HR-TO-DATE  BILLED-TO-DATE
# count            0.0  164.000000      164.000000
# mean             NaN   29.307927     3846.694573
# std              NaN   83.788706     9983.430896
# min              NaN    0.000000        0.000000
# 25%              NaN    0.000000        0.000000
# 50%              NaN    0.000000        0.000000
# 75%              NaN    0.000000        0.000000
# max              NaN  371.000000    42762.080000

# %%
cmp.shape
# Out:
# (164, 62)

# %%
cmp['Design Engineer'] = cmp['PROJECT-ID'] + '-' + cmp['DESIGN-ENGINEER']
cmp.head()
# Out:
#      WEEK-OF               PROJECT-ID  DESIGN-ENGINEER        CURRENT-PACKAGE  \
# 0 2020-07-12          TL13804 Z519147  Marissa Metzger        4.1 -- FINAL OH
# 1 2020-07-12        TL13804 Z519147-F       Ryan Gokey       3.4 -- 90 FOUND.
# 2 2020-07-12    TL13810 Z97249 Z96761      Nico Pecori  5.1 -- CONST. SUPPORT
# 3 2020-07-12      TL612 TL604 Z279897     Shiva Kaitha    2.2 -- 60 OH DESIGN
# 4 2020-07-12  TL13834 Z224371 P193412  Marissa Metzger          1 -- FIELDING
#
#         PACKAGE-STATUS     PACKAGE- ROADBLOCK    BIC       NEXT-SUBMITTAL  \
# 0        4 -- Approved           No Roadblock    NaN        Not Scheduled
# 1  5 -- Hold/Cancelled           No Roadblock    NaN        Not Scheduled
# 2       3 -- Roadblock  Submitted / In-Review  SDG&E        Not Scheduled
# 3  5 -- Hold/Cancelled                  Other   BMcD        Not Scheduled
# 4     2 -- In Progress           No Roadblock   ASEC  2020-07-24 00:00:00
#
#                    NEXT-SUBMITTAL DETAIL  \
# ...

# %%
cmp.drop('Design Engineer', axis=1, inplace=True)
cmp.head()
# Out:
#      WEEK-OF               PROJECT-ID  DESIGN-ENGINEER        CURRENT-PACKAGE  \
# 0 2020-07-12          TL13804 Z519147  Marissa Metzger        4.1 -- FINAL OH
# 1 2020-07-12        TL13804 Z519147-F       Ryan Gokey       3.4 -- 90 FOUND.
# 2 2020-07-12    TL13810 Z97249 Z96761      Nico Pecori  5.1 -- CONST. SUPPORT
# 3 2020-07-12      TL612 TL604 Z279897     Shiva Kaitha    2.2 -- 60 OH DESIGN
# 4 2020-07-12  TL13834 Z224371 P193412  Marissa Metzger          1 -- FIELDING
#
#         PACKAGE-STATUS     PACKAGE- ROADBLOCK    BIC       NEXT-SUBMITTAL  \
# 0        4 -- Approved           No Roadblock    NaN        Not Scheduled
# 1  5 -- Hold/Cancelled           No Roadblock    NaN        Not Scheduled
# 2       3 -- Roadblock  Submitted / In-Review  SDG&E        Not Scheduled
# 3  5 -- Hold/Cancelled                  Other   BMcD        Not Scheduled
# 4     2 -- In Progress           No Roadblock   ASEC  2020-07-24 00:00:00
#
#                    NEXT-SUBMITTAL DETAIL  \
# ...

# %%
cmp.rename(columns = {"WEEK-OF": "Wk-Off", "PROJECT-ID": "Prj-ID"})
cmp.head()f
# Out:
#      WEEK-OF               PROJECT-ID  DESIGN-ENGINEER        CURRENT-PACKAGE  \
# 0 2020-07-12          TL13804 Z519147  Marissa Metzger        4.1 -- FINAL OH
# 1 2020-07-12        TL13804 Z519147-F       Ryan Gokey       3.4 -- 90 FOUND.
# 2 2020-07-12    TL13810 Z97249 Z96761      Nico Pecori  5.1 -- CONST. SUPPORT
# 3 2020-07-12      TL612 TL604 Z279897     Shiva Kaitha    2.2 -- 60 OH DESIGN
# 4 2020-07-12  TL13834 Z224371 P193412  Marissa Metzger          1 -- FIELDING
#
#         PACKAGE-STATUS     PACKAGE- ROADBLOCK    BIC       NEXT-SUBMITTAL  \
# 0        4 -- Approved           No Roadblock    NaN        Not Scheduled
# 1  5 -- Hold/Cancelled           No Roadblock    NaN        Not Scheduled
# 2       3 -- Roadblock  Submitted / In-Review  SDG&E        Not Scheduled
# 3  5 -- Hold/Cancelled                  Other   BMcD        Not Scheduled
# 4     2 -- In Progress           No Roadblock   ASEC  2020-07-24 00:00:00
#
#                    NEXT-SUBMITTAL DETAIL  \
# ...
